# %% [markdown]
# **Name** - Aditya Singh Tomar
#
# ---
#
#
# **task**- CREDIT CARD FRAUDDETECTION

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data= pd.read_csv('/content/fraudTest.csv')

# %%
data
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                0   2020-06-21 12:14:25     2291163933867244
# 1                1   2020-06-21 12:14:33     3573030041201292
# 2                2   2020-06-21 12:14:53     3598215285024754
# 3                3   2020-06-21 12:15:15     3591919803438423
# 4                4   2020-06-21 12:15:17     3526826139003047
# ...            ...                   ...                  ...
# 143682      143682   2020-08-10 14:32:10       36078114201167
# 143683      143683   2020-08-10 14:32:20     3582754887089201
# 143684      143684   2020-08-10 14:32:23       30242921189660
# 143685      143685   2020-08-10 14:32:41     3540862542587229
# 143686      143686   2020-08-10 14:32:54  4560004149983868183
#
#                                     merchant        category    amt  \
# 0                      fraud_Kirlin and Sons   personal_care   2.86
# 1                       fraud_Sporer-Keebler   personal_care  29.84
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 143682      143682   2020-08-10 14:32:10       36078114201167
# 143683      143683   2020-08-10 14:32:20     3582754887089201
# 143684      143684   2020-08-10 14:32:23       30242921189660
# 143685      143685   2020-08-10 14:32:41     3540862542587229
# 143686      143686   2020-08-10 14:32:54  4560004149983868183
#
#                        merchant        category    amt        first      last  \
# 143682  fraud_Reichert-Weissnat          travel   6.03  Christopher      Horn
# 143683        fraud_Waelchi Inc       kids_pets  57.27     Terrance  Mckinney
# 143684    fraud_Lubowitz-Walter       kids_pets  20.87       Dalton     Jones
# 143685        fraud_Friesen Ltd  health_fitness  85.02        Nancy     Roach
# 143686                    fraud             NaN    NaN          NaN       NaN
#
#        gender                             street  ...      lat      long  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143687 entries, 0 to 143686
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             143687 non-null  int64
#  1   trans_date_trans_time  143687 non-null  object
#  2   cc_num                 143687 non-null  int64
#  3   merchant               143687 non-null  object
#  4   category               143686 non-null  object
#  5   amt                    143686 non-null  float64
#  6   first                  143686 non-null  object
#  7   last                   143686 non-null  object
#  8   gender                 143686 non-null  object
#  9   street                 143686 non-null  object
#  10  city                   143686 non-null  object
#  11  state                  143686 non-null  object
#  12  zip                    143686 non-null  float64
#  13  lat                    143686 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 1
# amt                      1
# first                    1
# last                     1
# gender                   1
# street                   1
# city                     1
# state                    1
# zip                      1
# lat                      1
# long                     1
# city_pop                 1
# job                      1
# dob                      1
# trans_num                1
# unix_time                1
# merch_lat                1
# merch_long               1
# is_fraud                 1
# dtype: int64

# %%
data['is_fraud'].value_counts()
# Out:
# is_fraud
# 0.0    143059
# 1.0       627
# Name: count, dtype: int64

# %%
legit = data[data.is_fraud == 0.0]
fraud = data[data.is_fraud == 1.0]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (143059, 23)
# (627, 23)

# %%
legit.merch_long	.describe()
# Out:
# count    143059.000000
# mean        -90.232318
# std          13.757331
# min        -166.671575
# 25%         -96.914007
# 50%         -87.422758
# 75%         -80.271748
# max         -66.952352
# Name: merch_long, dtype: float64

# %%
fraud.merch_long.describe()
# Out:
# count    627.000000
# mean     -90.810458
# std       14.339746
# min     -156.480766
# 25%      -96.334332
# 50%      -87.826081
# 75%      -80.953594
# max      -66.960745
# Name: merch_long, dtype: float64

# %%
credit_card_data = data.drop(columns='is_fraud', axis=1)
credit_card_data
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                0   2020-06-21 12:14:25     2291163933867244
# 1                1   2020-06-21 12:14:33     3573030041201292
# 2                2   2020-06-21 12:14:53     3598215285024754
# 3                3   2020-06-21 12:15:15     3591919803438423
# 4                4   2020-06-21 12:15:17     3526826139003047
# ...            ...                   ...                  ...
# 143682      143682   2020-08-10 14:32:10       36078114201167
# 143683      143683   2020-08-10 14:32:20     3582754887089201
# 143684      143684   2020-08-10 14:32:23       30242921189660
# 143685      143685   2020-08-10 14:32:41     3540862542587229
# 143686      143686   2020-08-10 14:32:54  4560004149983868183
#
#                                     merchant        category    amt  \
# 0                      fraud_Kirlin and Sons   personal_care   2.86
# 1                       fraud_Sporer-Keebler   personal_care  29.84
# ...

# %%
credit_card_data_with_fraud = data.copy()

# %%
new_dataset = credit_card_data_with_fraud.sample(frac=1)

# %%
X = new_dataset.drop(columns='is_fraud', axis=1)
Y = new_dataset['is_fraud']

# %%
print(X)
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 9692         9692   2020-06-23 22:24:11  4390966588600992777
# 4396         4396   2020-06-22 15:46:34     3566094707272327
# 8955         8955   2020-06-23 18:39:25     4364010865167176
# 4020         4020   2020-06-22 14:04:29     4586810168620942
# 10859       10859   2020-06-24 13:19:44     3502088871723054
# ...           ...                   ...                  ...
# 14868       14868   2020-06-26 12:01:16  4560395181594436016
# 15101       15101   2020-06-26 14:04:15  4897067971111209737
# 13409       13409   2020-06-25 19:08:30     6011504998544485
# 985           985   2020-06-21 17:50:55     4155021259183870
# 12283       12283   2020-06-25 06:13:37     4836998673805450
#
#                                   merchant        category     amt     first  \
# 9692                      fraud_Kub-Heaney  health_fitness   10.51      Kyle
# ...

# %%
print(Y)
# Out:
# 9692     0.0
# 4396     0.0
# 8955     0.0
# 4020     0.0
# 10859    0.0
#         ...
# 14868    0.0
# 15101    0.0
# 13409    0.0
# 985      0.0
# 12283    0.0
# Name: is_fraud, Length: 15582, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (143687, 22) (114949, 22) (28738, 22)

# %%
X_test
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 122261      122261   2020-08-03 04:39:40     4904681492230012
# 81476        81476   2020-07-19 21:05:54     3598014571045296
# 100679      100679   2020-07-26 17:04:12     2291163933867244
# 122679      122679   2020-08-03 07:54:13     4492491748959010
# 175            175   2020-06-21 13:12:03     2285066385084291
# ...            ...                   ...                  ...
# 91208        91208   2020-07-22 17:43:40       30404291151692
# 137984      137984   2020-08-08 22:25:43      343819048608995
# 94119        94119   2020-07-24 03:31:52  4855488158131690372
# 86901        86901   2020-07-21 06:21:47      370877495212014
# 97613        97613   2020-07-25 16:24:45     2235613922823698
#
#                                       merchant        category     amt  \
# 122261                         fraud_Marks Inc   gas_transport   40.51
# 81476                       fraud_Roob-Okuneva  health_fitness   16.36
# ...

# %%
Y_test
# Out:
# 122261    0.0
# 81476     0.0
# 100679    0.0
# 122679    0.0
# 175       0.0
#          ...
# 91208     0.0
# 137984    1.0
# 94119     0.0
# 86901     0.0
# 97613     0.0
# Name: is_fraud, Length: 28738, dtype: float64
